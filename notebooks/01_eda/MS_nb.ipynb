# %% [markdown]
# Ноутбук выполнения задач практики 1 - линейная регрессия

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression, ElasticNet
import numpy as np
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_validate, KFold, train_test_split
from sklearn.pipeline import make_pipeline
from phik.report import plot_correlation_matrix
from pathlib import Path
import os

# %%
df = pd.read_csv(r"..\..\data\raw\train.csv")
df.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %%
df_clean = df.set_index('id')
df_clean.head()
# Out:
#     MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# id
# 0                  5                   8                5              8
# 1                  6                   7                4              4
# 2                  6                   5                6              7
# 3                  3                   4                6              5
# 4                  5                   3                2              6
#
#     Urbanization  ClimateChange  DamsQuality  Siltation  \
# id
# 0              6              4            4          3
# 1              8              8            3          5
# 2              3              7            1          5
# 3              4              8            4          7
# 4              4              4            3          3
#
#     AgriculturalPractices  Encroachments  ...  DrainageSystems  \
# id                                        ...
# 0                       3              4  ...                5
# ...

# %%
from ydata_profiling import ProfileReport

df_clean = df.set_index('id')
profile = ProfileReport(df_clean, title="Flood Prediction EDA")
profile.to_file("../../reports/eda_report_cleaned.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# 100%|██████████| 21/21 [00:00<00:00, 45.08it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5388\1486707865.py in ?()
#       1 from ydata_profiling import ProfileReport
#       2
#       3 df_clean = df.set_index('id')
#       4 profile = ProfileReport(df_clean, title="Flood Prediction EDA")
# ----> 5 profile.to_file("../../reports/eda_report_cleaned.html")
#
# d:\urfu\envs\ml-python311\Lib\site-packages\ydata_profiling\profile_report.py in ?(self, output_file, silent)
# ...

# %%
# corr_matrix = df_clean.phik_matrix()
# plot_correlation_matrix(corr_matrix.values, x_labels=corr_matrix.columns, y_labels=corr_matrix.index, figsize=(10, 8))
# Out:
# interval columns not set, guessing: ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement', 'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality', 'Siltation', 'AgriculturalPractices', 'Encroachments', 'IneffectiveDisasterPreparedness', 'DrainageSystems', 'CoastalVulnerability', 'Landslides', 'Watersheds', 'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss', 'InadequatePlanning', 'PoliticalFactors', 'FloodProbability']
