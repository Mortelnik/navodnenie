# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\project1_navodnenie\navodnenie\data\raw\test.csv')

df.head()
# Out:
#         id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0  1117957                 4                   6                3
# 1  1117958                 4                   4                2
# 2  1117959                 1                   3                6
# 3  1117960                 2                   4                4
# 4  1117961                 6                   3                2
#
#    Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0              5             6              7            8          7
# 1              9             5              5            4          7
# 2              5             7              2            4          6
# 3              6             4              5            4          3
# 4              4             6              4            5          5
#
#    AgriculturalPractices  ...  IneffectiveDisasterPreparedness  \
# 0                      8  ...                                8
# ...
